# %%
# %%

import numpy as np
import pyvista as pv
import matplotlib.pyplot as plt 
import pandas as pd
import os
# change the path to the directory where the file is located
os.chdir(os.path.dirname(os.path.abspath(__file__)))

# ==================================================================
# load nodes and elements dataframes
# ==================================================================
mesh = pv.read("results/mesh.vtk")
info = {
    "RegularDomain": 1,
    "DRMDomain": 2,
    "PMLDomain": 3,
}
# filter cells with Domin tag 1
indices = mesh['Domain'] == 1
grid = mesh.extract_cells(indices)
cleangrid = grid.copy()
cleangrid.clear_data()

# ==================================================================
# create interface mesh
# ==================================================================
data = np.loadtxt("results/interfaceInfo.dat")
interface = pv.PolyData(data[:,1:4])

# ==================================================================
# beam mesh
# ==================================================================
beamnodes = np.loadtxt("results/beamNodes.dat")
beamcells = np.loadtxt("results/beamElems.dat", dtype=int)
beamnodes = beamnodes[:,1:]
beamcells[:,0] = 2
beamcells[:,1:] = beamcells[:,1:] - 1
celltypes  = np.ones(beamcells.shape[0],dtype= int) * pv.CellType.LINE
beam = pv.UnstructuredGrid(beamcells.tolist(),celltypes.tolist(),beamnodes.tolist())


# # ==================================================================
# # view the mesh
# # ==================================================================
# pl = pv.Plotter()
# pl.add_mesh(mesh,scalars="Domain", show_edges=True, color="white", opacity=1.0)
# pl.add_mesh(interface, color="red", line_width=5)
# pl.add_mesh(beam, color="blue", line_width=5)
# # pl.save_graphic("results/mesh.png")
# pl.show()
# exit()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /home/amnp95/Projects/OpenSeesProjects/PML_DRM_Pile/Pilewithfoundaton/Postprocess.py:5
#       3 import pyvista as pv
#       4 import matplotlib.pyplot as plt
# ----> 5 import pandas as pd
#       6 import os
#       7 # change the path to the directory where the file is located
#
# ModuleNotFoundError: No module named 'pandas'

# %%
#%%

griddispn  = np.loadtxt("results/NodeAcclPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
# plt.xlim(right=1.0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /home/amnp95/Projects/OpenSeesProjects/PML_DRM_Pile/Pilewithfoundaton/Postprocess.py:6
#       4 griddispn = griddispn[:,1:]
#       5 griddispx = griddispn[:,0::3]
# ----> 6 index      = grid.find_closest_point([0,0,0])
#       7 index2     = grid.find_closest_point([1,0,0])
#       8 index3     = grid.find_closest_point([7.,0,0])
#
# NameError: name 'grid' is not defined

# %%
# %%

import numpy as np
import pyvista as pv
import matplotlib.pyplot as plt 
import os
# change the path to the directory where the file is located
os.chdir(os.path.dirname(os.path.abspath(__file__)))

# ==================================================================
# load nodes and elements dataframes
# ==================================================================
mesh = pv.read("results/mesh.vtk")
info = {
    "RegularDomain": 1,
    "DRMDomain": 2,
    "PMLDomain": 3,
}
# filter cells with Domin tag 1
indices = mesh['Domain'] == 1
grid = mesh.extract_cells(indices)
cleangrid = grid.copy()
cleangrid.clear_data()

# ==================================================================
# create interface mesh
# ==================================================================
data = np.loadtxt("results/interfaceInfo.dat")
interface = pv.PolyData(data[:,1:4])

# ==================================================================
# beam mesh
# ==================================================================
beamnodes = np.loadtxt("results/beamNodes.dat")
beamcells = np.loadtxt("results/beamElems.dat", dtype=int)
beamnodes = beamnodes[:,1:]
beamcells[:,0] = 2
beamcells[:,1:] = beamcells[:,1:] - 1
celltypes  = np.ones(beamcells.shape[0],dtype= int) * pv.CellType.LINE
beam = pv.UnstructuredGrid(beamcells.tolist(),celltypes.tolist(),beamnodes.tolist())


# # ==================================================================
# # view the mesh
# # ==================================================================
# pl = pv.Plotter()
# pl.add_mesh(mesh,scalars="Domain", show_edges=True, color="white", opacity=1.0)
# pl.add_mesh(interface, color="red", line_width=5)
# pl.add_mesh(beam, color="blue", line_width=5)
# # pl.save_graphic("results/mesh.png")
# pl.show()
# exit()

# %%
# %%

# ==================================================================
# loading Accelerations
# ==================================================================
# griddisp   = np.loadtxt("results/NodeAccl0.out")
# time       = griddisp[:,0]
# griddisp   = griddisp[:,1:]
# griddispx  = griddisp[:,0::3]
# index      = grid.find_closest_point([0,0,0])
# index2     = grid.find_closest_point([1,0,0])
# index3     = grid.find_closest_point([7.,0,0])
# plt.plot(time, griddispx[:,index])
# plt.plot(time, griddispx[:,index2])
# plt.plot(time, griddispx[:,index3])
# plt.show()

# %%
#%%

griddispn  = np.loadtxt("results/NodeAcclPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
# plt.xlim(right=1.0)
plt.show()

# %%
#%%

griddispn  = np.loadtxt("results/NodeAcclPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
# plt.xlim(right=1.0)
plt.show()

# %%
#%%

griddispn  = np.loadtxt("results/NodeAcclPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
# plt.xlim(right=1.0)
plt.show()

# %%
#%%

griddispn  = np.loadtxt("results/NodeAcclPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
# plt.xlim(right=1.0)
plt.show()

# %%
#%%

griddispn  = np.loadtxt("results/NodeAcclPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
# plt.xlim(right=1.0)
plt.show()

# %%
#%%

griddispn  = np.loadtxt("results/NodeAcclPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
plt.xlim(right=5.0)
plt.show()

# %%
#%%

griddispn  = np.loadtxt("results/NodeAcclPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
plt.xlim(right=5.0)
plt.show()

# %%
#%%

griddispn  = np.loadtxt("results/NodeAcclPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
plt.xlim(right=5.0)
plt.show()

# %%
#%%

griddispn  = np.loadtxt("results/NodeAcclPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
plt.xlim(right=5.0)
plt.show()

# %%
# %%

# # %%

# %%
#%%

griddispn  = np.loadtxt("results/NodeAcclPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
plt.xlim(right=5.0)
plt.show()

# %%
#%%

griddispn  = np.loadtxt("results/NodeAcclPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
plt.xlim(right=5.0)
plt.show()

# %%
#%%

griddispn  = np.loadtxt("results/NodeDispPML0.out")
time      = griddispn[:,0]
griddispn = griddispn[:,1:]
griddispx = griddispn[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
plt.xlim(right=5.0)
plt.show()

# %%
# %%

index      = grid.find_closest_point([0,0,1])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
plt.xlim(right=5.0)
plt.show()

# %%
# %%

index      = grid.find_closest_point([0,0,1])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([5.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
plt.xlim(right=5.0)
plt.show()

# %%
# %%

# ==================================================================
# loading Accelerations
# ==================================================================
griddisp   = np.loadtxt("results/NodeAcclPML10.out")
time       = griddisp[:,0]
griddisp   = griddisp[:,1:]
griddispx  = griddisp[:,0::3]
index      = grid.find_closest_point([0,0,0])
index2     = grid.find_closest_point([1,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
plt.show()

# %%
# %%

# ==================================================================
# loading Accelerations
# ==================================================================
griddisp   = np.loadtxt("results/NodeAcclPML10.out")
time       = griddisp[:,0]
griddisp   = griddisp[:,1:]
griddispx  = griddisp[:,0::3]
index      = grid.find_closest_point([0,0,1])
index2     = grid.find_closest_point([0,0,0])
index3     = grid.find_closest_point([7.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
plt.show()

# %%
# %%

index      = grid.find_closest_point([0,0,1])
index2     = grid.find_closest_point([0,0,0])
index3     = grid.find_closest_point([5.,0,0])
plt.plot(time, griddispx[:,index])
plt.plot(time, griddispx[:,index2])
plt.plot(time, griddispx[:,index3])
# beamdispx = beamdisp[:,0::3]
# plt.plot(time, beamdispx[:,-1])
plt.xlim(right=5.0)
plt.show()

# %%
# %%

# ==================================================================
# loading Accelerations
# ==================================================================
griddisp   = np.loadtxt("results/NodeAcclPML10.out")
griddispn  = np.loadtxt("results/NodeAcclPML0.out")

# %%
# %%

# # %%
data1 = np.loadtxt("results/NodeAcclPML0.out")
data2 = np.loadtxt("results/NodeAcclPML10.out")

# %%
# %%

i = grid.find_closest_point([0,0,0])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim(right=2.5)
# Out:
# (-0.3989, 2.5)

# %%
# %%

i = grid.find_closest_point([0,0,0])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

i = grid.find_closest_point([0,0,1])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

i = grid.find_closest_point([0,0,-2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

i = grid.find_closest_point([0,0,-1])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

i = grid.find_closest_point([0,0,-5])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

i = grid.find_closest_point([0,0,-6])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

i = grid.find_closest_point([0,0,-6])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
# plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

i = grid.find_closest_point([0,0,-7])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
# plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

i = grid.find_closest_point([0,0,-7])
# plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.11180000000000001, 2.3698)

# %%
# %%

# # %%
data1 = np.loadtxt("results/NodeAcclPML0.out")
data2 = np.loadtxt("results/NodeAcclPML10.out")

# %%
# %%

i = grid.find_closest_point([0,0,-7])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

i = grid.find_closest_point([0,0,0])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

i = grid.find_closest_point([6,0,0])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

# # %%
data1 = np.loadtxt("results/NodeAcclPML0.out")
data2 = np.loadtxt("results/NodeAcclPML10.out")

# %%
# %%

i = grid.find_closest_point([0,0,0])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,0])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/NodeAcclPML0.out")
data2 = np.loadtxt("results/NodeAcclPML10.out")
i = grid.find_closest_point([0,0,0])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.xlim()
# Out:
# (-0.3989, 8.3989)

# %%
# %%

data1 = np.loadtxt("results/NodeAcclPML0.out")
data2 = np.loadtxt("results/NodeAcclPML10.out")
i = grid.find_closest_point([0,0,0])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.legend(["PML=5layers","PML=4layers"])

# %%
# %%

data1 = np.loadtxt("results/NodeAcclPML0.out")
data2 = np.loadtxt("results/NodeAcclPML10.out")
i = grid.find_closest_point([0,0,0])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.legend(["PML=5layers","PML=4layers"])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/NodeAcclPML0.out")
data2 = np.loadtxt("results/NodeAcclPML10.out")
i = grid.find_closest_point([0,0,0])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.legend(["PML=5layers","PML=4layers"])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/NodeAcclPML0.out")
data2 = np.loadtxt("results/NodeAcclPML10.out")
i = grid.find_closest_point([0,0,0])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.legend(["PML=5layers","PML=4layers"])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/NodeAcclPML0.out")
data2 = np.loadtxt("results/NodeAcclPML10.out")
i = grid.find_closest_point([0,0,0])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.legend(["PML=5layers","PML=4layers"])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])

# %%
# %%

data1 = np.loadtxt("results/NodeAcclPML0.out")
data2 = np.loadtxt("results/NodeAcclPML10.out")
i = grid.find_closest_point([0,0,0])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
plt.legend(["PML=5layers","PML=4layers"])

# %%
# %%

data1 = np.loadtxt("results/BeamDispPML0.out")
data2 = np.loadtxt("results/BeamDispPML10.out")

i = beam.find_closest_point([0,0,2])
plt.plot(data2[:,0],(data2[:,1::3])[:,i])
plt.plot(data1[:,0],(data1[:,1::3])[:,i])
